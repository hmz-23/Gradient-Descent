# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
X, y = datasets.make_regression(n_samples=500, n_features=1, n_informative=1, noise=30, random_state=0)

# %%
plt.scatter(X,y)

# %%
X
# Out:
# array([[ 0.6203583 ],
#        [ 0.01050002],
#        [ 0.09395323],
#        [-1.67600381],
#        [ 1.48051479],
#        [ 0.23218104],
#        [-0.90876325],
#        [ 0.34965446],
#        [ 0.33890413],
#        [-0.39727181],
#        [-0.4664191 ],
#        [ 1.89588918],
#        [ 0.40198936],
#        [ 0.60631952],
#        [ 0.69845715],
#        [ 1.11701629],
#        [-0.57884966],
#        [-0.20690368],
#        [-0.0525673 ],
#        [ 0.0519454 ],
#        [ 0.33367433],
#        [-1.07075262],
#        [ 0.370825  ],
#        [ 0.2799246 ],
#        [ 1.84926373],
#        [ 0.77179055],
#        [-0.41361898],
#        [ 0.5785215 ],
#        [ 0.3024719 ],
#        [ 0.04949498],
#        [-1.53624369],
#        [ 0.1666735 ],
#        [-1.25279536],
#        [-1.00021535],
#        [ 0.64013153],
#        [ 1.13689136],
#        [ 1.91006495],
#        [-0.85409574],
#        [ 0.14195316],
#        [ 0.16422776],
#        [ 0.17742614],
# ...

# %%
X.shape
# Out:
# (500, 1)

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print(X_train.shape)
# Out:
# (400, 1)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()

# %%
LR .fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([44.78474542])

# %%
LR.intercept_
# Out:
# -2.9778997684267123

# %%
epochs = 2500
lr = 0.001 

m=0
b=0

for i in range(epochs):
    
    y_pred = m * X_train.reshape(400) + b
    
    loss = sum(y_train - y_pred)**2/len(X_train)
    
    d_m = (-2/len(X_train)) * sum((y_train - y_pred) * X_train.reshape(400))
    
    d_b = (-2/len(X_train)) * sum(y_train - y_pred)
    
    m = m - (lr*d_m)
    b = b - (lr*d_b)
    
    print("The loss after",i,"iteration",loss)
# Out:
# The loss after 0 iteration 5338.43372176558
# The loss after 1 iteration 5313.279946659828
# The loss after 2 iteration 5288.243099315685
# The loss after 3 iteration 5263.322642559793
# The loss after 4 iteration 5238.518041661223
# The loss after 5 iteration 5213.828764320541
# The loss after 6 iteration 5189.254280658814
# The loss after 7 iteration 5164.794063206742
# The loss after 8 iteration 5140.447586893734
# The loss after 9 iteration 5116.214329037201
# The loss after 10 iteration 5092.093769331673
# The loss after 11 iteration 5068.085389838189
# The loss after 12 iteration 5044.188674973566
# The loss after 13 iteration 5020.403111499812
# The loss after 14 iteration 4996.728188513554
# The loss after 15 iteration 4973.163397435503
# The loss after 16 iteration 4949.70823199997
# The loss after 17 iteration 4926.362188244457
# The loss after 18 iteration 4903.124764499293
# The loss after 19 iteration 4879.99546137724
# The loss after 20 iteration 4856.973781763263
# ...

# %%
print(m)
print(b)
